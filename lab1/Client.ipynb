# %% [markdown]
# # Telefonauskunft Client Notebook
#
# Hier testen wir den Telefonauskunft-Dienst. Der Server muss zuerst gestartet werden!
#
# **Stellen Sie sicher, dass der Server läuft, bevor Sie die Client-Operationen ausführen.**

# %%
import clientserver # import from our script

client = clientserver.Client() # Create a client instance

client.GET("Yusuf") # Get all entries and print them
client.GETALL() # Get all entries and print them
# Out:
# 2025-11-05 11:55:35,756 - vs2lab.a1_layers.clientserver.Client - INFO - Client connected to socket <socket.socket fd=81, family=2, type=1, proto=0, laddr=('127.0.0.1', 32782), raddr=('127.0.0.1', 50007)>
# 2025-11-05 11:55:35,758 - vs2lab.a1_layers.clientserver.Client - INFO - Client down.
# Yusuf: 13245

# %% [markdown]
# Finished.

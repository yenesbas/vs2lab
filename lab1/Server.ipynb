# %% [markdown]
# # Telefonauskunft Server Notebook
#
# ## Übersicht
# Dieses Notebook startet den **Telefonauskunft-Server**, der Anfragen von Clients bearbeitet.
#
# ## Funktionalität
# Der Server bietet zwei Hauptfunktionen:
# - **GET [Name]**: Sucht eine spezifische Telefonnummer
# - **GETALL**: Gibt alle Einträge aus dem Telefonbuch zurück
#
# ## Wichtige Hinweise
# ⚠️ **Dieses Notebook muss ZUERST gestartet werden, bevor das Client-Notebook verwendet wird!**
#
# Der Server läuft auf:
# - Host: localhost (127.0.0.1)
# - Port: 50007
#
# ## Nächste Schritte
# 1. Führen Sie die unten stehende Code-Zelle aus
# 2. Der Server wartet dann auf Client-Verbindungen
# 3. Öffnen Sie das Client-Notebook in einem separaten Tab
# 4. Zum Beenden drücken Sie Strg+C oder stoppen den Kernel

# %%
import clientserver # import from our script

server = clientserver.Server() # Create a server instance

server.serve() # start server routine in the forked process

# %% [markdown]
# ## Server starten
#
# Der folgende Code:
# 1. Importiert unser `clientserver` Modul
# 2. Erstellt eine Server-Instanz (bindet sich an den Socket)
# 3. Startet die Server-Schleife (wartet auf Client-Anfragen)
#
# **Nach dem Ausführen läuft der Server und wartet auf Verbindungen!**

# %% [markdown]
# ## Server beendet
#
# ✅ **Der Server wurde erfolgreich beendet.**
#
# ### Was ist passiert?
# - Der Server hat Client-Anfragen verarbeitet
# - Alle Socket-Verbindungen wurden ordnungsgemäß geschlossen
# - Der Server-Prozess ist gestoppt
#
# ### Logging-Ausgaben
# Die Log-Nachrichten zeigen:
# - Wann der Server gestartet wurde
# - Welche Client-Verbindungen verarbeitet wurden
# - Wann der Server heruntergefahren wurde
#
# ### Neustart
# Um den Server erneut zu starten, führen Sie einfach die Code-Zelle oben erneut aus.

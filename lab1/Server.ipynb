# %% [markdown]
# # Running server and client in separate notebooks - server part
# This is the first notebook we need to run in this constelation. Note that the client notebook needs to be run now in a separate window.

# %%
import clientserver # import from our script

server = clientserver.Server() # Create a server instance

server.serve() # start server routine in the forked process
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import clientserver # import from our script
#       3 server = clientserver.Server() # Create a server instance
#       5 server.serve() # start server routine in the forked process
#
# File /workspaces/vs2lab/lab1/clientserver.py:9
#       6 import socket
#       8 import const_cs
# ----> 9 from context import lab_logging
#      11 lab_logging.setup(stream_level=logging.INFO)  # init loging channels for the lab
#      13 # pylint: disable=logging-not-lazy, line-too-long
#
# File /workspaces/vs2lab/lab1/context.py:24
#      21 add_parent_path()
#      23 # following imports are used by other modules to access shared packages
# ---> 24 from lib import lab_logging, lab_channel # pylint: disable=import-error, unused-import, wrong-import-position
#
# File /workspaces/vs2lab/lab1/../lib/lab_channel.py:6
#       3 import pickle
#       4 import random
# ----> 6 import redis
#       9 class Channel:
#      10     """
#      11     Channel implements a communication channel for persistent asynchronous message exchange between member processes.
#      12     Member processes (short: members) have to explicitly join a common global channel and obtain an identifier.
#    (...)     41         Value: redis list of message objects send fom member1 to member2
#      42     """
#
# ModuleNotFoundError: No module named 'redis'

# %% [markdown]
# Finished
